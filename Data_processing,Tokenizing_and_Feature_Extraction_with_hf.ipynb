# %% [markdown]
# Tokenization

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, DistilBertTokenizer, DistilBertForSequenceClassification
from transformers import pipeline

# %%
model_name = "nlptown/bert-base-multilingual-uncased-sentiment"
mymodel = AutoModelForSequenceClassification.from_pretrained(model_name)
mytokenizer = AutoTokenizer.from_pretrained(model_name)

classifier = pipeline("sentiment-analysis", model = mymodel, tokenizer = mytokenizer)
res = classifier(" i wasw so happy with the movie")
print(res)
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# [{'label': '5 stars', 'score': 0.6682783365249634}]

# %% [markdown]
# step by step

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-cased")

text = "I was so happy with the film"

tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# ['I', 'was', 'so', 'happy', 'with', 'the', 'film']

# %% [markdown]
# convert tokens to ids

# %%
input_ids = tokenizer.convert_tokens_to_ids(tokens)
print(input_ids)
# Out:
# [146, 1108, 1177, 2816, 1114, 1103, 1273]

# %% [markdown]
# encoding text(tokenize + converting to input ids)

# %%
encoded_input = tokenizer(text)
print(encoded_input)
# Out:
# {'input_ids': [101, 146, 1108, 1177, 2816, 1114, 1103, 1273, 102], 'token_type_ids': [0, 0, 0, 0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1, 1, 1, 1]}

# %% [markdown]
# decode the text

# %%
decoded_output = tokenizer.decode(input_ids)
print(decoded_output)
# Out:
# I was so happy with the film
