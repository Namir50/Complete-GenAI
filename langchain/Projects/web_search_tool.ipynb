# %%
from langchain.tools import tool
from langchain.agents import create_agent
from dotenv import load_dotenv
from tavily import TavilyClient
from typing import Dict, Any
from langchain.messages import  HumanMessage, SystemMessage

# %%
load_dotenv()
# Out:
# True

# %%
tavily_client = TavilyClient()

# %%
@tool
def web_search_tool(query:str) -> Dict[str, Any]:
    """search the web for information"""

    return tavily_client.search(query)

# %%
web_search_tool.invoke("Who is the mayor of new york?")
# Out:
# {'query': 'Who is the mayor of new york?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://en.wikipedia.org/wiki/Mayor_of_New_York_City',
#    'title': 'Mayor of New York City - Wikipedia',
#    'content': 'The current mayor is Zohran Mamdani, who was elected on November 4, 2025, and took office shortly after midnight on January 1, 2026.\n\n## History\n\n[edit]\n\nSee also: List of mayors of New York City [...] | Seal of the City of New York |\n| Flag of the mayor of New York City |\n| Incumbent Zohran Mamdani since January 1, 2026 |\n| Government of New York City |\n| Style "Style (form of address)") | His Honor "Honour (style)"); Mr. Mayor (informal) |\n| Residence | Gracie Mansion |\n| Seat | New York City Hall |\n| Term length | Four years, renewable once consecutively |\n| Constituting instrument | New York City Charter |\n| Inaugural holder | Thomas Willett | [...] of the mayor. Cornelius W. Lawrence, a Democrat, was elected that year.',
#    'score': 0.8991304,
#    'raw_content': None,
#    'id': 'f8c1d7-00'},
#   {'url': 'https://www.nyc.gov/mayors-office',
#    'title': "Official Site of NYC Mayor Zohran Mamdani - NYC Mayor's Office",
#    'content': 'Zohran Mamdani was sworn in as Mayor of the City of New York on January 1st, 2026. Prior to becoming Mayor, he represented the 36th New York State Assembly District and its neighborhoods of Astoria, Ditmars-Steinway, and Astoria Heights.\n\n## Latest News\n\nSee all news\n\nMayor Mamdani Extend 2-K Offers to More Than 2,000 Children, Announce More Than 5,700 Applications Submitted [...] ##### Secure .gov websites use HTTPS\n\nA lock (🔒) or https:// means you’ve safely connected to the .gov website. Share sensitive information only on official, secure websites.\n\n### Top languages\n\n### More languages\n\nOffice of the Mayor\n\n# Welcome to the Mayor’s Office\n\n## Zohran Kwame Mamdani\n\n#### 112th Mayor of New York City [...] © City of New York.\n2026\nAll Rights Reserved. NYC is a trademark and service mark of the City of New York.',
#    'score': 0.8091708,
#    'raw_content': None,
#    'id': '10916d-01'},
#   {'url': 'https://x.com/NYCMayor?lang=en',
#    'title': 'Mayor Zohran Kwame Mamdani (@NYCMayor) / Posts / X - Twitter',
#    'content': "Log inSign up\n\nMayor Zohran Kwame Mamdani\n\n\n\nuser avatar\n\nMayor Zohran Kwame Mamdani\n\nFighting every day to deliver a city that working New Yorkers can actually afford. Mayor of New York City.\n\nNew York, NY\n\nJoined January 2009\n\n1,255\n\nFollowing2.4M\n\nFollowers\n\nRepliesRepliesArticlesArticlesMediaMedia\n\n Pinned\n\n  user avatar\n\n  Mayor Zohran Kwame Mamdani\n\n  @NYCMayor\n\n  Jul 27\n\n  Now serving: a new era for small business.\n\n  \n\n  00:00\n\n  525K\n user avatar\n\n  Mayor Zohran Kwame Mamdani [...] Aug 1\n\n  Yesterday, we gathered with hearts heavier than words can express to mourn a beloved son of the Bronx: 12-year-old Jacob Freytes. We stood alongside Jacob's mother, Migdalia Martinez, his family, friends, and with a community united in grief, to condemn the senseless act of\n\n  \n\n  \n\n  \n\n  108K\n user avatar\n\n  Mayor Zohran Kwame Mamdani\n\n  @NYCMayor\n\n  Aug 1\n\n  New York, we’re building tenant power across the city. Visit organize.nyc.gov to join a canvass. [...] @NYCMayor\n\n  4h\n\n  Public safety and accountability should go hand in hand. As chair of the New York City Civilian Complaint Review Board, the nation's largest independent police oversight body, Jennifer Jones Austin will bring an unwavering commitment to justice and transparency. Jennifer has\n\n  80K\n user avatar\n\n  Mayor Zohran Kwame Mamdani\n\n  @NYCMayor\n\n  6h",
#    'score': 0.7522497,
#    'raw_content': None,
#    'id': '33f121-02'},
#   {'url': 'https://ballotpedia.org/Eric_Adams_(New_York)',
#    'title': 'Eric Adams (New York) - Ballotpedia',
#    'content': 'Eric Adams (Democratic Party) was the Mayor of New York. He assumed office on January 1, 2022. He left office on January 1, 2026. [...] `<ref>`\n\n| Political offices | | |\n --- \n| Preceded by   Bill de Blasio (D) | Mayor of New York   2022-2026 | Succeeded by   Zohran Mamdani (D) |\n| Preceded by   - | Brooklyn Borough President   2013-2022 | Succeeded by   Antonio Reynoso (D) |\n| Preceded by   - | New York State Senate District 20   2007-2014 | Succeeded by   - |',
#    'score': 0.7418428,
#    'raw_content': None,
#    'id': 'cd2edb-03'},
#   {'url': 'https://www.instagram.com/nycmayor?hl=en',
#    'title': 'Mayor Zohran Kwame Mamdani (@nycmayor) • Instagram photos and videos',
#    'content': "Log In\n\nSign Up\n\n## nycmayor\n\n 3.7M followers\n 55 following\n\nMayor Zohran Kwame Mamdanihe/him/his\n\nFighting every day to deliver a city that working New Yorkers can actually afford. Mayor of New York City.\n\n Week 3\n\nPhoto by Mayor Zohran Kwame Mamdani on July 04, 2026. May be an image of the Statue of Liberty and text.\n\nPhoto by Mayor Zohran Kwame Mamdani on May 13, 2026. [...] Photo by Mayor Zohran Kwame Mamdani on August 01, 2026. May be an image of text that says 'Greta PI SUL S ስት Duzer VanDuzer zer an ۷ Howard Hotaro HowardAve Ave Ave 100+ City-owned properties are becoming thousands of affordable homes. And we're adding more every year.'.\n\nPhoto by Ciudad de Nueva York on August 01, 2026.\n\nPhoto by Mayor Zohran Kwame Mamdani on July 31, 2026. [...] Video by Mayor Zohran Kwame Mamdani on July 31, 2026. May be an image of one or more people, people standing, suit, brick wall and text that says '이지 it's it'stimetotalktrash time to talk trash'.\n\nShow more posts from nycmayor",
#    'score': 0.7300017,
#    'raw_content': None,
#    'id': 'ce77d6-04'}],
#  'response_time': 0.7,
#  'request_id': '04cdea53-0149-46cd-a83d-c1e7ab9c7c77'}

# %%
agent = create_agent(
    model = "google_genai:gemini-3.6-flash",
    tools = [web_search_tool],
)

response = agent.invoke(
    {"messages": [HumanMessage(content = "Who is the mayor of new york?")]}
)

response
# Out:
# {'messages': [HumanMessage(content='Who is the mayor of new york?', additional_kwargs={}, response_metadata={}, id='9bfee1e9-1cf5-4e2a-80e7-a5026dea3d01'),
#   AIMessage(content=[], additional_kwargs={'function_call': {'name': 'web_search_tool', 'arguments': '{"query": "current mayor of new york city"}'}, '__gemini_function_call_thought_signatures__': {'JnDKoTCc': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.6-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019fd29c-e88a-7862-8aa9-a65172bc2377-0', tool_calls=[{'name': 'web_search_tool', 'args': {'query': 'current mayor of new york city'}, 'id': 'JnDKoTCc', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 53, 'output_tokens': 148, 'total_tokens': 201, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 125}}),
#   ToolMessage(content='{"query": "current mayor of new york city", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://web.archive.org/web/20170411100334/https://en.wikipedia.org/wiki/Mayor_of_New_York_City", "title": "Mayor of New York City - Wikipedia", "content": "## Contents\\n\\n## Current mayor[edit]\\n\\nThe current mayor is Democrat \\"Democratic Party (United States)\\") Bill de Blasio, who was elected on November 5, 2013.\\n\\n## History of the office[edit] [...] # Mayor of New York City\\n\\n| Mayor of the City of New York | |\\n --- |\\n| Flag of the Mayor of New York City.svg Flag of the Mayor | |\\n| Bill de Blasio 11-2-2013.jpg Incumbent  Bill de Blasio  since January 1, 2014 | |\\n| Style \\"Style (manner of address)\\") | His/Her Honor |\\n| Residence | Gracie Mansion |\\n| Term length | Four years; may serve two consecutive terms |\\n| Inaugural holder | Thomas Willett |\\n| Formation | 17th century |\\n| Salary | $225,000 |\\n| Website | www.nyc.gov/mayor | [...] Flag of the Mayor of New York City.svg\\nBill de Blasio 11-2-2013.jpg\\n\\nThe Mayor of the City of New York is head of the executive branch of New York City\'s government. The mayor\'s office administers all city services, public property, police and fire protection, most public agencies, and enforces all city, state and federal laws within New York City.", "score": 0.9191869, "raw_content": null, "id": "62eb1b-00"}, {"url": "https://web.archive.org/web/20170411100328/https://en.wikipedia.org/wiki/Mayor_of_New_York_City", "title": "Mayor of New York City - Wikipedia", "content": "## Contents\\n\\n## Current mayor[edit]\\n\\nThe current mayor is Democrat \\"Democratic Party (United States)\\") Bill de Blasio, who was elected on November 5, 2013.\\n\\n## History of the office[edit] [...] # Mayor of New York City\\n\\n| Mayor of the City of New York | |\\n --- |\\n| Flag of the Mayor of New York City.svg Flag of the Mayor | |\\n| Bill de Blasio 11-2-2013.jpg Incumbent  Bill de Blasio  since January 1, 2014 | |\\n| Style \\"Style (manner of address)\\") | His/Her Honor |\\n| Residence | Gracie Mansion |\\n| Term length | Four years; may serve two consecutive terms |\\n| Inaugural holder | Thomas Willett |\\n| Formation | 17th century |\\n| Salary | $225,000 |\\n| Website | www.nyc.gov/mayor | [...] Flag of the Mayor of New York City.svg\\nBill de Blasio 11-2-2013.jpg\\n\\nThe Mayor of the City of New York is head of the executive branch of New York City\'s government. The mayor\'s office administers all city services, public property, police and fire protection, most public agencies, and enforces all city, state and federal laws within New York City.", "score": 0.9191869, "raw_content": null, "id": "c2947a-01"}, {"url": "https://web.archive.org/web/20161127025307/https://en.wikipedia.org/wiki/Mayor_of_New_York_City", "title": "Mayor of New York City - Wikipedia", "content": "## Contents\\n\\n## Current mayor[edit]\\n\\nThe current mayor is Democratic Party Democrat&action=edit&redlink=1 \\"(United States) (page does not exist)\\") Bill de Blasio, who was elected on November 5, 2013.\\n\\n## History of the office[edit] [...] # Mayor of New York City\\n\\n| Mayor of the City of New York | |\\n --- |\\n| Flag of the Mayor of New York City.svg Flag of the Mayor | |\\n| Incumbent  Bill de Blasio  since January 1, 2014 | |\\n| Style \\"Style (manner of address)\\") | Your Honor |\\n| Residence | Gracie Mansion |\\n| Term length | Four years; may serve two consecutive terms |\\n| Inaugural holder | Thomas Willett |\\n| Formation | 17th century |\\n| Salary | $225,000 |\\n| Website | www.nyc.gov/mayor |\\n\\nFlag of the Mayor of New York City.svg [...] --- \\n|  | |\\n|  Van Wyck (1898–1901)  Low (1902–1903)  McClellan (1904–1909)  Gaynor (1910–1913)  Kline (1913)  Mitchel (1914–1917)  Hylan (1918–1925)  Walker (1926–1932)  McKee (1932)  O\'Brien (1933)  LaGuardia (1934–1945)  O\'Dwyer (1946–1950)  Impelitteri (1950–1953)  W ...
#   AIMessage(content=[], additional_kwargs={'function_call': {'name': 'web_search_tool', 'arguments': '{"query": "who is the current mayor of New York City 2026 OR 2025"}'}, '__gemini_function_call_thought_signatures__': {'CB5kbiyY': 'EngKdgERTTIPOSjTjgVq3UTSit6izJl76osAJF2qSi7ZZl0UUDZRFa+9mnp0OlHSnpijXwDvzymbEpnlKr7ttLGNeV9OM3d6Z3saVHNKajVrVcSm8+4ROn2Svd3pljFqQtSNYpZAYMhuoJXmOII4ZxcizJeyCBdoQQ0='}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.6-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019fd29c-f574-7612-9004-3e5de2f9e674-0', tool_calls=[{'name': 'web_search_tool', 'args': {'query': 'who is the current mayor of New York City 2026 OR 2025'}, 'id': 'CB5kbiyY', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 2439, 'output_tokens': 53, 'total_tokens': 2492, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 16}}),
#   ToolMessage(content='{"query": "who is the current mayor of New York City 2026 OR 2025", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://en.wikipedia.org/wiki/Mayor_of_New_York_City", "title": "Mayor of New York City", "content": "The current mayor is Zohran Mamdani, who was elected on November 4, 2025, and took office shortly after midnight on January 1, 2026.\\n\\n## History\\n\\n[edit]\\n\\nSee also: List of mayors of New York City [...] | Seal of the City of New York |\\n| Flag of the mayor of New York City |\\n| Incumbent Zohran Mamdani since January 1, 2026 |\\n| Government of New York City |\\n| Style \\"Style (form of address)\\") | His Honor \\"Honour (style)\\"); Mr. Mayor (informal) |\\n| Residence | Gracie Mansion |\\n| Seat | New York City Hall |\\n| Term length | Four years, renewable once consecutively |\\n| Constituting instrument | New York City Charter |\\n| Inaugural holder | Thomas Willett | [...] |  Van Wyck (1898–1901)  Low (1902–1903)  McClellan (1904–1909)  Gaynor (1910–1913)  Kline (1913)  Mitchel (1914–1917)  Hylan (1918–1925)  Collins (1925)  Walker (1926–1932)  McKee (1932)  O\'Brien (1933)  La Guardia (1934–1945)  O\'Dwyer (1946–1950)  Impelitteri (1950–1953)  Wagner (1954–1965)  Lindsay (1966–1973)  Beame (1974–1977)  Koch (1978–1989)  Dinkins (1990–1993)  Giuliani (1994–2001)  Bloomberg (2002–2013)  de Blasio (2014–2021)  Adams (2022–2025)  Mamdani (2026–present) |\\n| Category |", "score": 0.9073207, "raw_content": null, "id": "834c44-00"}, {"url": "https://en.wikipedia.org/wiki/2025_New_York_City_mayoral_election", "title": "2025 New York City mayoral election - Wikipedia", "content": "Laura Gillen, NY-4 (2025–present) (Democratic) (endorsed against Mamdani)\\n Josh Gottheimer, NJ-5 (2017–present) (Democratic) (endorsed against Mamdani)\\n George Latimer \\"George Latimer (New York politician)\\"), NY-16 (2025–present) (Democratic)\\n Gregory Meeks, NY-5 (1998–present) (Democratic)[better source needed]\\n Josh Riley, NY-19 (2025–present) (Democratic)\\n Mikie Sherrill, former NJ-11 (2019–2026) and governor of New Jersey (2026–present) (Democratic) [...] \\") state assemblyman Zohran Mamdani won the election with 50.78% of the vote, defeating Republican \\"Republican Party (United States)\\") activist Curtis Sliwa and independent former Democratic governor Andrew Cuomo. This election featured the highest turnout for a New York City mayoral election since 1993, mainly due to significant young voter registration. Mamdani succeeded Democratic incumbent Eric Adams on January 1, 2026, becoming the first Muslim and first South Asian mayor of New York City, [...] Jennifer Jones Austin, lawyer and nonprofit CEO\\n Jamaal Bowman, former U.S. representative from New York\'s 16th congressional district (2021–2025) (endorsed Mamdani)\\n Justin Brannan, city councilmember from the 47th district (2018–2025) (running for comptroller)\\n Kathryn Garcia, New York State director of Operations (2021–2026), former commissioner of the New York City Department of Sanitation (2014–2020), and candidate for mayor in 2021", "score": 0.87782305, "raw_content": null, "id": "e77044-01"}, {"url": "https://www.facebook.com/theoceanicpress/posts/as-of-march-21-2026-zohran-mamdani-is-new-york-citys-mayor-having-been-sworn-in-/122167112510853703", "title": "As of March 21, 2026, Zohran Mamdani... - The Oceanic Press", "content": "## The Oceanic Press\'s post\\n\\n### The Oceanic Press\\n\\n20 March  ·\\n\\nAs of March 21, 2026, Zohran Mamdani is New York City’s mayor, having been sworn in on January 1, 2026 after previously serving in the New York State Assembly. Since taking office, he has moved quickly on a number of high-profile issues, including reversing some late Eric Adams executive orders and launching new city initiatives, which has kept him at the center of sharp political debate.", "score": 0.8533396, "raw_content": null, "id": "9636ce-02"}, {"url": "https://www.instagram.com ...
#   AIMessage(content=[{'type': 'text', 'text': 'The mayor of New York City is **Zohran Mamdani**. He assumed office as the 111th mayor of New York City on January 1, 2026, succeeding Eric Adams.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.6-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019fd29d-00be-7021-924d-15bce4a2caa7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 4721, 'output_tokens': 146, 'total_tokens': 4867, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 101}})]}

# %%
print(response["messages"][-1].content[0]['text'])
# Out:
# The mayor of New York City is **Zohran Mamdani**. He assumed office as the 111th mayor of New York City on January 1, 2026, succeeding Eric Adams.
